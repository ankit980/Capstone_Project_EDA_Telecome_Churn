# %% [markdown]
# **Loading Data and Import Filamina**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#import and mount the dataset from drive
url='https://drive.google.com/file/d/19FfTrGFiIb-Aw-8gNMiggCwLS_65EtpD/view?usp=share_link'
url='https://drive.google.com/uc?id='+url.split('/')[-2]
df=pd.read_csv(url)

# %%
#Viewing the data from csv file & get all column dada
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#data from buttom side
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
#getting shape of dataset
df.shape
# Out:
# (3333, 20)

# %%
#data types of all the columns
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
#deatails about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
#its getting unique values for each attribute
df.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
#discription of the data set 
df.describe(include='all').T
# Out:
#                          count unique    top  freq        mean        std  \
# State                     3333     51     WV   106         NaN        NaN
# Account length          3333.0    NaN    NaN   NaN  101.064806  39.822106
# Area code               3333.0    NaN    NaN   NaN  437.182418   42.37129
# International plan        3333      2     No  3010         NaN        NaN
# Voice mail plan           3333      2     No  2411         NaN        NaN
# Number vmail messages   3333.0    NaN    NaN   NaN     8.09901  13.688365
# Total day minutes       3333.0    NaN    NaN   NaN  179.775098  54.467389
# Total day calls         3333.0    NaN    NaN   NaN  100.435644  20.069084
# Total day charge        3333.0    NaN    NaN   NaN   30.562307   9.259435
# Total eve minutes       3333.0    NaN    NaN   NaN  200.980348  50.713844
# Total eve calls         3333.0    NaN    NaN   NaN  100.114311  19.922625
# Total eve charge        3333.0    NaN    NaN   NaN    17.08354   4.310668
# ...

# %% [markdown]
# **Get Area code exculde duplicate**

# %%
df['Area code'].unique()
# Out:
# array([415, 408, 510])

# %% [markdown]
# **Count of Area Code**

# %%
Count_of_AC_415=(df['Area code']==415)
Count_of_AC_415.count()
# Out:
# 3333

# %%
Count_of_AC_510=(df['Area code']==510)
Count_of_AC_510.count()
# Out:
# 3333

# %%
Count_of_AC_408=(df['Area code']==408)
Count_of_AC_408.count()
# Out:
# 3333

# %%
data_area_code=(df['Area code']==510)

# %%
df.loc[data_area_code,['International plan','Voice mail plan']]
# Out:
#      International plan Voice mail plan
# 5                   Yes              No
# 6                    No             Yes
# 13                   No              No
# 17                   No              No
# 18                   No             Yes
# ...                 ...             ...
# 3304                Yes              No
# 3316                 No             Yes
# 3320                Yes              No
# 3330                 No              No
# 3331                Yes              No
#
# [840 rows x 2 columns]

# %% [markdown]
# **`Call Details for particular Area Code:`**

# %%
Call_details=df.loc[data_area_code,['Total day calls','Total eve calls','Total night calls','Total intl calls','Customer service calls']]

# %%
Call_details
# Out:
#       Total day calls  Total eve calls  Total night calls  Total intl calls  \
# 5                  98              101                118                 6
# 6                  88              108                118                 7
# 13                 88               75                115                 5
# 17                114              111                121                 3
# 18                 66               65                108                 5
# ...               ...              ...                ...               ...
# 3304              114              140                 80                 5
# 3316              111               96                108                 9
# 3320              101               77                133                 4
# 3330              109               58                 91                 6
# 3331              105               84                137                10
#
#       Customer service calls
# ...

# %% [markdown]
# **Call details of Charge Data**

# %%
Call_details_charge=df.loc[data_area_code,['Total day charge','Total eve charge','Total night charge','Total intl charge']]

# %%
Call_details_charge
# Out:
#       Total day charge  Total eve charge  Total night charge  \
# 5                37.98             18.75                9.18
# 6                37.09             29.62                9.57
# 13               26.62             21.05                8.65
# 17               32.42             18.55                5.83
# 18               32.25             18.09                7.46
# ...                ...               ...                 ...
# 3304             31.64             16.88                9.29
# 3316             27.90             18.62                9.91
# 3320             23.80             16.69                5.40
# 3330             30.74             24.55                8.64
# 3331             36.35             13.57                6.26
#
#       Total intl charge
# 5                  1.70
# 6                  2.03
# 13                 3.32
# 17                 2.19
# 18                 2.70
# ...                 ...
# 3304               3.73
# 3316               3.32
# ...

# %%
# duplicate_value=tele_df[tele_df.duplicated()]
# tele_df[duplicate_value]
len(df[df.duplicated()])
# Out:
# 0

# %%
Duplicate_state=(df['State'].duplicated())
df[Duplicate_state]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 14      IA              62        415                 No              No
# 24      VA             132        510                 No              No
# 27      MT              54        408                 No              No
# 28      MO              20        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
Duplicate_night_minute=(df['Total night minutes'].duplicated())
df.loc[Duplicate_night_minute,['Total night minutes','State']]
# Out:
#       Total night minutes State
# 20                  208.8    FL
# 54                  203.9    WY
# 67                  129.3    MN
# 86                  189.6    IN
# 91                  196.0    LA
# ...                   ...   ...
# 3327                221.4    SC
# 3329                191.3    WV
# 3330                191.9    RI
# 3331                139.2    CT
# 3332                241.4    TN
#
# [1742 rows x 2 columns]

# %%
Duplicate_night_minute=(df['Number vmail messages'].duplicated())
df.loc[Duplicate_night_minute,['Number vmail messages','State']]
# Out:
#       Number vmail messages State
# 3                         0    OH
# 4                         0    OK
# 5                         0    AL
# 7                         0    MO
# 8                         0    LA
# ...                     ...   ...
# 3328                     36    AZ
# 3329                      0    WV
# 3330                      0    RI
# 3331                      0    CT
# 3332                     25    TN
#
# [3287 rows x 2 columns]

# %% [markdown]
# **Finding Null values**

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# **State vise Voice mail plan**

# %%
# Voice mail according to state
Vmail=(df['Number vmail messages']>0)

# %%
df.loc[Vmail,['Number vmail messages','State']]
# Out:
#       Number vmail messages State
# 0                        25    KS
# 1                        26    OH
# 6                        24    MA
# 9                        37    WV
# 16                       27    ID
# ...                     ...   ...
# 3306                     29    AL
# 3315                     18    ME
# 3316                     29    MS
# 3328                     36    AZ
# 3332                     25    TN
#
# [922 rows x 2 columns]

# %% [markdown]
# **Max plan taken by city**

# %%
df.loc[Vmail,['Number vmail messages','State']].max()
# Out:
# Number vmail messages    51
# State                    WY
# dtype: object

# %%
Churn_data=df['Churn']
df[Churn_data]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 41      MD             135        408                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3301    CA              84        415                 No              No
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df['Churn'].unique()
# Out:
# array([False,  True])

# %%
churn_data=df.Churn.value_counts()

# %%
d=[]
for value in churn_data:
  d.append(value)
d
# Out:
# [2850, 483]

# %% [markdown]
# **CHURN REPRESENTATION**

# %%
fig = plt.figure(figsize =(5, 5))
plt.pie(d,labels = ['False','True'],autopct='%1.1f%%')
plt.title("Pie chart for Churn")
# show plot
plt.show()

# %%
sns.countplot(x=df.Churn)

# %% [markdown]
# **Statewise Churn Record**

# %%
df['State'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,15))
ax=sns.countplot(x='State',hue='Churn',data=df)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(20,15))
ax=sns.barplot(x='State',y='Churn',data=df)
plt.show()

# %% [markdown]
# **Percentage of Churn With State**

# %%
plt.rcParams['figure.figsize']=(20,15)

((df.groupby(['State'])['Churn'].mean())*100).plot.bar(color=['violet','indigo','b','g','y','orange','r'])
# plt.figure(figsize=(35,18))
plt.title("State with most churn %")
plt.xlabel('state',fontsize=15)
plt.ylabel('percentage',fontsize=15)
# Out:
# Text(0, 0.5, 'percentage')

# %% [markdown]
# **Display mostly churn State Data**

# %%
df.groupby(['State'])['Churn'].mean().sort_values(ascending=False).head()
# Out:
# State
# NJ    0.264706
# CA    0.264706
# TX    0.250000
# MD    0.242857
# SC    0.233333
# Name: Churn, dtype: float64

# %% [markdown]
# **Dispaly minimum churn data**

# %%
df.groupby(['State'])['Churn'].mean().sort_values(ascending=True).head()
# Out:
# State
# HI    0.056604
# AK    0.057692
# AZ    0.062500
# VA    0.064935
# IA    0.068182
# Name: Churn, dtype: float64

# %% [markdown]
# **Area Code with Churn %**

# %%
Area_code=df['Area code'],df['Churn']
sns.set(style='darkgrid')
# plt.figure(figsize=(10,9))
ax=sns.barplot(x='Area code',y='Churn',data=df)
plt.show()

# %% [markdown]
# **Customer service calls	with Area Code**

# %%
Customer_Service=df['Area code'],df['Customer service calls']
sns.set(style='darkgrid')
# plt.figure(figsize=(9,5))
ax=sns.barplot(x='Area code',y='Customer service calls',data=df)
plt.show()

# %% [markdown]
# **Analysing International plan**

# %%
df['International plan'].value_counts()
# Out:
# No     3010
# Yes     323
# Name: International plan, dtype: int64

# %% [markdown]
# **International plan vs churn**

# %%
International_plan_data=pd.crosstab(df['International plan'],df['Churn'])
International_plan_data
# Out:
# Churn               False  True
# International plan
# No                   2664   346
# Yes                   186   137

# %%
fig = plt.figure(figsize =(7, 5))
data=df['International plan'].value_counts()
plt.pie(data,autopct='%1.1f%%',labels=['No','Yes'])
plt.title("International plan")
plt.show()

# %%
sns.countplot(x='International plan',hue="Churn",data=df)

# %%
plan=df['International plan'],df['Churn']
sns.set(style='darkgrid')
# plt.figure(figsize=(10,7))
ax=sns.barplot(x='International plan',y='Churn',data=df)
plt.show()

# %%
plan=df['International plan'],df['Area code']
sns.set(style='darkgrid')
# plt.figure(figsize=(10,5))
ax=sns.barplot(x='International plan',y='Area code',data=df)
plt.show()

# %% [markdown]
# **Lets analysis Voice Mail**

# %%
voice_mail=df['Voice mail plan'].value_counts()
voice_mail
# Out:
# No     2411
# Yes     922
# Name: Voice mail plan, dtype: int64

# %%
voice_churn_data=pd.crosstab(df['Voice mail plan'],df['Churn'])
voice_churn_data
# Out:
# Churn            False  True
# Voice mail plan
# No                2008   403
# Yes                842    80

# %%
fig = plt.figure(figsize =(7, 5))
plt.pie(voice_mail,autopct='%1.1f%%',labels=['No','Yes'],colors=['orange','green'])
plt.title("voice mail plan")
plt.show()

# %%
sns.countplot(x='Voice mail plan',hue='Churn',data=df)
#if you use countplot method then x x-axis should not present with y-axis change the name of y-axis as hue or use another method name as "barplot"

# %% [markdown]
# **vmail messages**

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
#show the data of 'Number vmail messages' 
df['Number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9])

# %%
#show the data of 'Number vmail messages count

df['Number vmail messages'].value_counts()
# Out:
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 22      32
# 35      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 50       2
# 9        2
# 8        2
# 11       2
# 48       2
# 49       1
# 4        1
# 10       1
# 51       1
# Name: Number vmail messages, dtype: int64

# %%
#Show the details of 'Number vmail messages' data
df['Number vmail messages'].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: Number vmail messages, dtype: float64

# %%
# Table cross wise data of vmail and churn
Vmail=pd.crosstab(df['Number vmail messages'],df['Churn'])
Vmail
# Out:
# Churn                  False  True
# Number vmail messages
# 0                       2008   403
# 4                          1     0
# 8                          2     0
# 9                          2     0
# 10                         1     0
# 11                         2     0
# 12                         6     0
# 13                         4     0
# 14                         7     0
# 15                         8     1
# 16                        12     1
# 17                        13     1
# 18                         5     2
# 19                        18     1
# 20                        20     2
# 21                        26     2
# 22                        30     2
# 23                        36     0
# 24                        41     1
# 25                        37     0
# 26                        35     6
# 27                        41     3
# 28                        45     6
# 29                        45     8
# 30                        42     2
# ...

# %%
sns.distplot(df['Number vmail messages'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x='Number vmail messages',hue='Churn',data=df)

# %%
df.boxplot(column='Number vmail messages', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# **Analysing "Customer service calls" column**

# %%
df['Customer service calls'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8])

# %%
df['Customer service calls'].value_counts()
# Out:
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: Customer service calls, dtype: int64

# %%
customer_ser_call=pd.crosstab(df['Customer service calls'],df['Churn'])
customer_ser_call
# Out:
# Churn                   False  True
# Customer service calls
# 0                         605    92
# 1                        1059   122
# 2                         672    87
# 3                         385    44
# 4                          90    76
# 5                          26    40
# 6                           8    14
# 7                           4     5
# 8                           1     1
# 9                           0     2

# %%
sns.countplot(x='Customer service calls',hue='Churn',data=df)

# %% [markdown]
# **Initalized text analysis by Day Call**

# %%
# mean value of churned and not churned customer 
(df.groupby(["Churn"])['Total day calls'].mean())
# Out:
# Churn
# False    100.283158
# True     101.335404
# Name: Total day calls, dtype: float64

# %%
#Print the mean value of churned and not churned customer 
(df.groupby(["Churn"])['Total day minutes'].mean())
# Out:
# Churn
# False    175.175754
# True     206.914079
# Name: Total day minutes, dtype: float64

# %%
#Print the mean value of churned and not churned customer 
(df.groupby(["Churn"])['Total day charge'].mean())
# Out:
# Churn
# False    29.780421
# True     35.175921
# Name: Total day charge, dtype: float64

# %%
sns.scatterplot(x="Total day calls", y="Total day charge", hue="Churn", data=df,palette='hls')

# %%
sns.scatterplot(x="Total day minutes", y="Total day charge", hue="Churn", data=df,palette='hls')

# %%
fig = plt.figure(figsize =(40, 20))
sns.countplot(x='Total day calls',hue='Churn',data=df)

# %% [markdown]
# **Analysis of evening calls**

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Evening call minutes analysis with churn
df.groupby(['Churn'])['Total eve minutes'].mean()
# Out:
# Churn
# False    199.043298
# True     212.410145
# Name: Total eve minutes, dtype: float64

# %%
#Evening charge analysis with churn
df.groupby(['Churn'])['Total eve charge'].mean()
# Out:
# Churn
# False    16.918909
# True     18.054969
# Name: Total eve charge, dtype: float64

# %%
#Total Evening call  analysis with churn
df.groupby(['Churn'])['Total eve calls'].mean()
# Out:
# Churn
# False    100.038596
# True     100.561077
# Name: Total eve calls, dtype: float64

# %%
sns.scatterplot(x="Total eve minutes",y="Total eve charge",hue="Churn",data=df)

# %%
sns.boxplot(x="Total eve minutes", y="Total eve charge", hue="Churn", data=df,palette='hls')

# %% [markdown]
# **Analysing night calls**

# %%
df.groupby(["Churn"])["Total night minutes"].mean()
# Out:
# Churn
# False    200.133193
# True     205.231677
# Name: Total night minutes, dtype: float64

# %%
df.groupby(["Churn"])["Total night calls"].mean()
# Out:
# Churn
# False    100.058246
# True     100.399586
# Name: Total night calls, dtype: float64

# %%
df.groupby(["Churn"])["Total night charge"].mean()
# Out:
# Churn
# False    9.006074
# True     9.235528
# Name: Total night charge, dtype: float64

# %%
sns.scatterplot(x="Total night minutes",y="Total night charge",hue="Churn",data=df)

# %% [markdown]
# **Analysing Intl calls**

# %%
df.groupby(["Churn"])["Total intl minutes"].mean()
# Out:
# Churn
# False    10.158877
# True     10.700000
# Name: Total intl minutes, dtype: float64

# %%
df.groupby(["Churn"])["Total intl calls"].mean()
# Out:
# Churn
# False    4.532982
# True     4.163561
# Name: Total intl calls, dtype: float64

# %%
df.groupby(["Churn"])["Total intl charge"].mean()
# Out:
# Churn
# False    2.743404
# True     2.889545
# Name: Total intl charge, dtype: float64

# %%
sns.scatterplot(x="Total intl minutes",y="Total intl charge",hue="Churn",data=df)

# %%
#Deriving a relation between overall call charge and overall call minutes   
day_charge_perm = df['Total day charge'].mean()/df['Total day minutes'].mean()
eve_charge_perm = df['Total eve charge'].mean()/df['Total eve minutes'].mean()
night_charge_perm =df['Total night charge'].mean()/df['Total night minutes'].mean()
int_charge_perm= df['Total intl charge'].mean()/df['Total intl minutes'].mean()

# %%
sns.barplot(x=['Day','Evening','Night','International'],y=[day_charge_perm,eve_charge_perm,night_charge_perm,int_charge_perm])

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# ***Graphical represnatation of each numerical column present in the data set excluded boolean and obj***

# %%
df1=df.select_dtypes(exclude=['object','bool'])
df1
# Out:
#       Account length  Area code  Number vmail messages  Total day minutes  \
# 0                128        415                     25              265.1
# 1                107        415                     26              161.6
# 2                137        415                      0              243.4
# 3                 84        408                      0              299.4
# 4                 75        415                      0              166.7
# ...              ...        ...                    ...                ...
# 3328             192        415                     36              156.2
# 3329              68        415                      0              231.1
# 3330              28        510                      0              180.8
# 3331             184        510                      0              213.8
# 3332              74        415                     25              234.4
#
#       Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# ...

# %%
for column in df1:
        plt.figure(figsize=(17,1))
        sns.displot(data=df1, x=column)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
# ...

# %%
# visualization using correlation plot
plt.figure(figsize=(19,10))
df.corr()['Churn'].sort_values(ascending = False).plot(kind='bar',color = ['red','blue','yellow','indigo','orange','brown','pink'])

# %% [markdown]
# **Correlation Heatmap Of All Data Together**

# %%
df['Churn'] = df['Churn'].replace({bool(True):1,bool(False):0})
plt.figure(figsize=(17,9))
sns.heatmap(df.corr(), cmap="Paired",annot=False)
plt.title("Correlation Heatmap", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')
